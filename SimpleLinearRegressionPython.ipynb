# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("data/SaratogaHouses.csv")

# %%
dataset.head()
# Out:
#    Unnamed: 0   price  lotSize  age  landValue  livingArea  pctCollege  \
# 0           1  132500     0.09   42      50000         906          35
# 1           2  181115     0.92    0      22300        1953          51
# 2           3  109000     0.19  133       7300        1944          51
# 3           4  155000     0.41   13      18700        1944          51
# 4           5   86060     0.11    0      15000         840          51
#
#    bedrooms  fireplaces  bathrooms  rooms          heating      fuel  \
# 0         2           1        1.0      5         electric  electric
# 1         3           0        2.5      6  hot water/steam       gas
# 2         4           1        1.0      8  hot water/steam       gas
# 3         3           1        1.5      5          hot air       gas
# 4         2           0        1.0      3          hot air       gas
#
#                sewer waterfront newConstruction centralAir
# 0             septic         No              No         No
# 1             septic         No              No         No
# 2  public/commercial         No              No         No
# 3             septic         No              No         No
# 4  public/commercial         No             Yes        Yes

# %%
X = dataset['livingArea'].values
y = dataset['price'].values

# %%
y
# Out:
# array([132500, 181115, 109000, ..., 194900, 125000, 111300], shape=(1728,))

# %%
mean_x = np.mean(X)
mean_y = np.mean(y)

# %%
numer = 0
denom = 0

for i in range(len(X)):
    numer += (X[i] - mean_x) * (y[i] - mean_y)
    denom += (X[i] - mean_x) ** 2

slope = numer/denom
c = mean_y - mean_x * slope


# y = b0+b1x
# y = c+mx

# %%
slope, c
# Out:
# (np.float64(113.1225418468094), np.float64(13439.394004889764))

# %%
from scipy.stats import linregress

# %%
linregress(X,y)
# Out:
# LinregressResult(slope=np.float64(113.12254184680957), intercept=np.float64(13439.394004889473), rvalue=np.float64(0.7123902334268238), pvalue=np.float64(9.486239939677656e-268), stderr=np.float64(2.682341003448628), intercept_stderr=np.float64(4992.352848756606))

# %%
predictions = []

for i in range(len(X)):
    y_pred = slope * X[i] + c
    predictions.append(y_pred)

# %%
plt.scatter(X,y)
plt.plot(X,predictions,color='red')#this line is known as best fit line

# %%
print(predictions[:10])
print(y[:10])
# Out:
# [np.float64(115928.41691809907), np.float64(234367.7182317085), np.float64(233349.61535508724), np.float64(233349.61535508724), np.float64(108462.32915620966), np.float64(143756.5622124142), np.float64(324752.6291673092), np.float64(201449.05855428698), np.float64(198055.3822988827), np.float64(173620.91325997186)]
# [132500 181115 109000 155000  86060 120000 153000 170000  90000 122900]

# %%
numer = 0
n = len(X)
for i in range(len(X)):
    numer += (predictions[i] - y[i]) ** 2

# MSE - Mean Squared Error
mse = numer / n

# RMSE - Root Mean Squared Error
rmse = np.sqrt(mse)

# %%
mse, rmse
# Out:
# (np.float64(4769912967.014983), np.float64(69064.55651790564))

# %%
newX = 906

# %%
pred_y = slope * newX + c

# %%
pred_y
# Out:
# np.float64(115928.41691809907)

# %%
y[0]
# Out:
# np.int64(132500)

# %%
(pred_y - y[0])
# Out:
# np.float64(-16571.583081900928)

# %%
def cost_function(X,b,y):
    pass

# %%
def gradient_descent(epochs, learning_rate, X,y):
    for epoch in range(epochs):
        pass
